# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo

# %%
## Mac Users
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
#!which chromedriver

# %%
# executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## Windows User

# %% [markdown]
# ## NASA Mars News

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
browser.visit(url)

# %%
# Iterate through all pages
News = []
for x in range(1):
    # HTML object
    html = browser.html
    # HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # all elements that contain title information
    News_titles = soup.find_all('div', class_='content_title')

    # Iterate through each title
    for div in News_titles:
        # Beautiful Soup's find() method to navigate and retrieve attributes
        a = div.find('a')
        news_title = a.text
        News.append({
            "news_title":news_title})

        print()
        print('-----------')
        print()
        print('news_title: ' + news_title)
# Out:
# -----------
#
# news_title: MarCO Makes Space for Small Explorers
#
# -----------
#
# news_title: Martian Skies Clearing over Opportunity Rover
#
# -----------
#
# news_title: Curiosity Surveys a Mystery Under Dusty Skies
#
# -----------
#
# news_title: NASA's InSight Has a Thermometer for Mars
#
# -----------
#
# news_title: Digital Creators: Apply for NASA Mars Landing Event
#
# -----------
#
# news_title: NASA's InSight Passes Halfway to Mars, Instruments Check In
#
# -----------
#
# news_title: Six Things About Opportunity's Recovery Efforts
#
# -----------
#
# news_title: Meet the People Behind NASA's InSight Mars Lander
#
# -----------
#
# news_title: Mars Terraforming Not Possible Using Present-Day Technology
#
# -----------
#
# news_title: Opportunity Hunkers Down During Dust Storm
#
# -----------
#
# news_title: NASA Statement on Possible Subsurface Lake near Martian South Pole
#
# -----------
#
# news_title: JPL's 'Martians' Are Coming to Griffith Observatory
#
# -----------
#
# news_title: NASA's MAVEN Spacecraft Finds That 'Stolen' Electrons Enable Unusual Aurora on Mars
#
# -----------
#
# news_title: 'Storm Chasers' on Mars Searching for Dusty Secrets
#
# -----------
#
# news_title: NASA Mars Mission Adds Southern California Dates
#
# -----------
#
# news_title: Curiosity Captures Photos of Thickening Dust
#
# -----------
#
# news_title: NASA Encounters the Perfect Storm for Science
#
# -----------
#
# news_title: Media Telecon About Mars Dust Storm, Opportunity
#
# -----------
#
# news_title: NASA Finds Ancient Organic Material, Mysterious Methane on Mars
#
# -----------
#
# news_title: NASA to Host Live Discussion on New Mars Science Results
#
# -----------
#
# news_title: Mars Curiosity's Labs Are Back in Action
#
# -----------
#
# news_title: NASA CubeSats Steer Toward Mars
#
# -----------
#
# news_title: Scientists Shrink Chemistry Lab to Seek Evidence of Life on Mars
#
# -----------
#
# news_title: InSight Steers Toward Mars
#
# -----------
#
# news_title: Drilling Success: Curiosity is Collecting Mars Rocks
#
# -----------
#
# news_title: NASA's Curiosity Rover Aims to Get Its Rhythm Back
#
# -----------
#
# news_title: A Pale Blue Dot, As Seen by a CubeSat
#
# -----------
#
# news_title: Mars Helicopter to Fly on NASA’s Next Red Planet Rover Mission
#
# -----------
#
# news_title: NASA's First Deep-Space CubeSats Say: 'Polo!'
#
# -----------
#
# news_title: NASA, ULA Launch Mission to Study How Mars Was Made
#
# -----------
#
# news_title: NASA’s First Mission to Study the Interior of Mars Awaits May 5 Launch
#
# -----------
#
# news_title: Vice President Pence Visits JPL, Previews NASA’s Next Mars Mission Launch
#
# -----------
#
# news_title: NASA Sets Sights on May 5 Launch of InSight to Mars
#
# -----------
#
# news_title: Results of Heat Shield Testing
#
# -----------
#
# news_title: NASA Engineers Dream Big with Small Spacecraft
#
# -----------
#
# news_title: Bound for Mars: Countdown to First Interplanetary Launch from California
#
# -----------
#
# news_title: NASA Invests in Visionary Technology
#
# -----------
#
# news_title: NASA is Ready to Study the Heart of Mars
#
# -----------
#
# news_title: ‘Marsquakes’ Could Shake Up Planetary Science
#
# -----------
#
# news_title: Mars Curiosity Celebrates Sol 2,000
#
# -----------
#
# news_title:
# NASA is Ready to Study the Heart of Mars
#
#
# -----------
#
# news_title:
# NASA Briefing on First Mission to Study Mars Interior
#
#
# -----------
#
# news_title:
# New 'AR' Mobile App Features 3-D NASA Spacecraft
#
#
# -----------
#
# news_title:
# Opportunity Hunkers Down During Dust Storm
#
#
# -----------
#
# news_title:
# NASA Finds Ancient Organic Material, Mysterious Methane on Mars
#
#
# -----------
#
# news_title:
# NASA Invests in Visionary Technology
#
#
# -----------
#
# news_title:
# NASA is Ready to Study the Heart of Mars
#
#
# -----------
#
# news_title:
# NASA Briefing on First Mission to Study Mars Interior
#
#
# -----------
#
# news_title:
# New 'AR' Mobile App Features 3-D NASA Spacecraft
#
#
# -----------
#
# news_title:
# Opportunity Hunkers Down During Dust Storm
#
#
# -----------
#
# news_title:
# NASA Finds Ancient Organic Material, Mysterious Methane on Mars
#
#
# -----------
#
# news_title:
# NASA Invests in Visionary Technology

# %%
# Iterate through all pages
for x in range(1):
    # HTML object
    html = browser.html
    # HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # all elements that contain title information
    news_ps = soup.find_all('div', class_='article_teaser_body')

    # Iterate through each title
    for div in news_ps:
        # Beautiful Soup's find() method to navigate and retrieve attributes
        news_p = div.text
        News.append({
            "news_p":news_p})
        print()
        print('----------------------------------')
        print()
        print('news_p: ' + news_p)
# Out:
# ----------------------------------
#
# news_p: A pair of NASA CubeSats flying to Mars are opening a new frontier for small spacecraft.
#
# ----------------------------------
#
# news_p: As the skies above Opportunity continue to clear, engineers at JPL are increasing the frequency of commands asking the solar-powered rover to communicate with Earth.
#
# ----------------------------------
#
# news_p: NASA's Curiosity rover surveyed its surroundings on Mars, producing a 360-degree panorama of its current location on Vera Rubin Ridge.
#
# ----------------------------------
#
# news_p: The mission's heat probe could reveal how the planet's towering volcanoes formed.
#
# ----------------------------------
#
# news_p: Up to 30 multimedia participants will be selected for a special two-day event at JPL culminating in the InSight spacecraft's landing on Mars. Apply by Sept. 3.
#
# ----------------------------------
#
# news_p: NASA's InSight spacecraft, en route to a Nov. 26 landing on Mars, passed the halfway mark on Aug. 6. All of its instruments have been tested and are working well.
#
# ----------------------------------
#
# news_p: The global dust storm on Mars could soon let in enough sunlight for the Opportunity rover to recharge.
#
# ----------------------------------
#
# news_p: A series of NASA videos highlight scientists and engineers leading the next mission to Mars.
#
# ----------------------------------
#
# news_p: Transforming the inhospitable Martian environment into a place astronauts could explore without life support is not possible without technology well beyond today’s capabilities.
#
# ----------------------------------
#
# news_p: It's the beginning of the end for the planet-encircling dust storm on Mars. But it could still be weeks, or even months, before skies are clear enough for NASA's Opportunity rover to recharge its batteries and phone home.
#
# ----------------------------------
#
# news_p: A new paper suggests that liquid water may be sitting under a layer of ice at Mars' south pole.
#
# ----------------------------------
#
# news_p: On July 30, when Mars and Earth are closer than they've been since 2003, JPL scientists and engineers will be at a free public event at Griffith Observatory in Los Angeles.
#
# ----------------------------------
#
# news_p: Auroras appear on Earth as ghostly displays of colorful light in the night sky, usually near the poles.
#
# ----------------------------------
#
# news_p: Scientists with NASA's Mars orbiters have been waiting years for an event like the current Mars global dust storm.
#
# ----------------------------------
#
# news_p: Looking for summer fun? Southern California families have their choice of the beach, movies, museums -- and even NASA's next mission to Mars.
#
# ----------------------------------
#
# news_p: A storm of tiny dust particles has engulfed much of Mars over the last two weeks.
#
# ----------------------------------
#
# news_p: One of the most intense Martian dust storms ever observed is being studied by a record number of NASA spacecraft.
#
# ----------------------------------
#
# news_p: NASA will host a media telecon on Wednesday, June 13, about a massive Martian dust storm affecting the Opportunity rover, and how various missions can obtain unique science.
#
# ----------------------------------
#
# news_p: NASA’s Curiosity rover has found evidence on Mars with implications for NASA’s search for life.
#
# ----------------------------------
#
# news_p: Questions are welcome during a live discussion at 11 a.m. PDT (2 p.m. EDT) Thursday, June 7, on new science results from NASA's Mars Curiosity rover.
#
# ----------------------------------
#
# news_p: NASA's Curiosity rover is analyzing drilled samples on Mars in one of its onboard labs for the first time in more than a year.
#
# ----------------------------------
#
# news_p: NASA has achieved a first for the class of tiny spacecraft known as CubeSats, which are opening new access to space.
#
# ----------------------------------
#
# news_p: An international team of scientists has created a tiny chemistry lab for a rover that will drill beneath the Martian surface looking for signs of past or present life.
#
# ----------------------------------
#
# news_p: The spacecraft has completed its first trajectory correction maneuver.
#
# ----------------------------------
#
# news_p: Engineers will now test delivering samples to instruments inside NASA's Curiosity Mars rover.
#
# ----------------------------------
#
# news_p: Rover engineers at JPL will try to restore percussive drilling on Mars this week, part of a larger series of tests that will last through summer.
#
# ----------------------------------
#
# news_p: One of NASA's MarCO CubeSats has taken its first image.
#
# ----------------------------------
#
# news_p: NASA is adding a Mars helicopter to the agency’s next mission to the Red Planet, Mars 2020.
#
# ----------------------------------
#
# news_p: MarCO is a pair of tiny spacecraft that launched with NASA's InSight lander today.
#
# ----------------------------------
#
# news_p: NASA’s Mars InSight mission launched this morning on a 300-million-mile trip to Mars to study for the first time what lies deep beneath the surface of the Red Planet.
#
# ----------------------------------
#
# news_p: All systems are go for NASA’s next launch to the Red Planet.
#
# ----------------------------------
#
# news_p: A week before NASA's next Mars launch, Vice President Mike Pence toured the birthplace of the InSight Mars Lander and numerous other past, present and future space missions.
#
# ----------------------------------
#
# news_p: NASA’s next mission to Mars, InSight, is scheduled to launch Saturday, May 5, on a first-ever mission to study the heart of the Red Planet.
#
# ----------------------------------
#
# news_p: A post-test inspection of the composite structure for a heat shield to be used on the Mars 2020 mission revealed that a fracture occurred during structural testing.
#
# ----------------------------------
#
# news_p: The first CubeSat mission to deep space will launch in May.
#
# ----------------------------------
#
# news_p: On May 5, millions of Californians may witness the historic first interplanetary launch from America’s West Coast.
#
# ----------------------------------
#
# news_p: NASA is investing in technology concepts, including several from JPL, that may one day be used for future space exploration missions.
#
# ----------------------------------
#
# news_p: NASA is about to go on a journey to study the center of Mars.
#
# ----------------------------------
#
# news_p: InSight, the next mission to the Red Planet, will use seismology to see into the depths of Mars.
#
# ----------------------------------
#
# news_p: NASA's Mars Curiosity rover just hit a new milestone: its two-thousandth Martian day on the Red Planet. An image mosaic taken recently offers a preview of what comes next.

# %% [markdown]
# ## JPL Mars Space Images - Featured Image

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url1 = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url1)

# %%
# Iterate through all pages
image_url = []
for x in range(1):
    # HTML object
    html = browser.html
    # HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # all elements that contain image information
    images = soup.find_all('div', class_='img')

    # Iterate through each title
    for div in images:
        # Beautiful Soup's find() method to navigate and retrieve attributes
        img = div.find('img')
        featured_image_url = img['src']
        image_url.append({
            "featured_image_url":featured_image_url})
        print()
        print('-----------')
        print()
        print('featured_image_url = ' + 'https://www.jpl.nasa.gov'+featured_image_url)
# Out:
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22711-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22710-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22709-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22708-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22707-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22706-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22679-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22545-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22678-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22677-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22684-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22683-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22682-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22681-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22676-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22675-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22671-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22670-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22669-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22668-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22667-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22666-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22665-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22664-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22663-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22647-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22624-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22623-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22622-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22621-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22620-640x350.jpg
#
# -----------
#
# featured_image_url = https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22546-640x350.jpg

# %% [markdown]
# ## Mars Weather

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url2 = 'https://twitter.com/marswxreport?lang=en'
browser.visit(url2)

# %%
# Iterate through all pages
weather =[]
for x in range(50):
    # HTML object
    html = browser.html
    # HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # all elements that contain weather information
    tweets = soup.find_all('p', class_='TweetTextSize TweetTextSize--normal js-tweet-text tweet-text')

    # Iterate through each title
    for p in tweets:
        # Beautiful Soup's find() method to navigate and retrieve attributes
        mars_weather = p.text
        weather.append({"mars_weather": mars_weather})
        print()
        print('-----------')
        print()
        print('mars_weather = ' + mars_weather)
# Out:
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# ...
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49
#
# -----------
#
# mars_weather = Sol 2171 (2018-09-14), high -12C/10F, low -65C/-84F, pressure at 8.79 hPa, daylight 05:43-17:59
#
# -----------
#
# mars_weather = Sol 2170 (2018-09-13), high -12C/10F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:42-17:59
#
# -----------
#
# mars_weather = Sol 2169 (2018-09-12), high -10C/14F, low -70C/-93F, pressure at 8.82 hPa, daylight 05:41-17:58
#
# -----------
#
# mars_weather = Sol 2168 (2018-09-11), high -13C/8F, low -69C/-92F, pressure at 8.99 hPa, daylight 05:41-17:57
#
# -----------
#
# mars_weather = Sol 2167 (2018-09-10), high -12C/10F, low -73C/-99F, pressure at 8.85 hPa, daylight 05:40-17:57
#
# -----------
#
# mars_weather = Mars Thermospheric Variability Revealed by MAVEN EUVM Solar Occultations: Structure at Aphelion and Perihelion and Response to EUV Forcingpic.twitter.com/0cCv8sUVjh
#
# -----------
#
# mars_weather = Sol 2166 (2018-09-09), high -10C/14F, low -72C/-97F, pressure at 8.87 hPa, daylight 05:40-17:56
#
# -----------
#
# mars_weather = Congrats to NASA/JPL for the Emmy Award for Outstanding Original Interactive Program for its coverage of the Cassini mission's Grand Finale at Saturn. https://www.jpl.nasa.gov/news/news.php?feature=7232 …https://twitter.com/VeronicaMcG/status/1039221529005813762 …
#
# -----------
#
# mars_weather = Sol 2165 (2018-09-08), high -10C/14F, low -70C/-93F, pressure at 8.87 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2164 (2018-09-07), high -8C/17F, low -68C/-90F, pressure at 8.86 hPa, daylight 05:39-17:55
#
# -----------
#
# mars_weather = Sol 2163 (2018-09-06), high -5C/23F, low -70C/-93F, pressure at 8.86 hPa, daylight 05:38-17:54
#
# -----------
#
# mars_weather = Mars is hard
#
# Jason Davis's Mars Exploration Family Portrait
# http://www.planetary.org/blogs/jason-davis/updated-mars-exploration-family-portrait.html …pic.twitter.com/kCCusty5hw
#
# -----------
#
# mars_weather = Sol 2162 (2018-09-05), high -5C/23F, low -69C/-92F, pressure at 8.85 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = This is how big Opportunity’s wheels arehttps://twitter.com/cirquelar/status/1037866353963593728 …
#
# -----------
#
# mars_weather = Sol 2161 (2018-09-04), high -5C/23F, low -68C/-90F, pressure at 8.84 hPa, daylight 05:37-17:53
#
# -----------
#
# mars_weather = Sol 2160 (2018-09-03), high -8C/17F, low -68C/-90F, pressure at 8.85 hPa, daylight 05:36-17:52
#
# -----------
#
# mars_weather = Sol 2159 (2018-09-02), high -10C/14F, low -68C/-90F, pressure at 8.83 hPa, daylight 05:36-17:51
#
# -----------
#
# mars_weather = Sol 2158 (2018-09-01), high -7C/19F, low -67C/-88F, pressure at 8.80 hPa, daylight 05:35-17:51
#
# -----------
#
# mars_weather = Sol 2157 (2018-08-31), high -5C/23F, low -67C/-88F, pressure at 8.77 hPa, daylight 05:35-17:50
#
# -----------
#
# mars_weather = Sol 2156 (2018-08-30), high -6C/21F, low -71C/-95F, pressure at 8.79 hPa, daylight 05:34-17:49

# %% [markdown]
# ## Mars Facts

# %%
url = 'https://space-facts.com/mars/'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                      0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.42 x 10^23 kg (10.7% Earth)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.52 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                  -153 to 20 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers]

# %%
df = tables[0]
df.columns = ['Fact','Value']
df.head()
# Out:
#                    Fact                          Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.42 x 10^23 kg (10.7% Earth)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.52 AU)

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Fact</th>\n      <th>Value</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Equatorial Diameter:</td>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Polar Diameter:</td>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Mass:</td>\n      <td>6.42 x 10^23 kg (10.7% Earth)</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Moons:</td>\n      <td>2 (Phobos &amp; Deimos)</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Orbit Distance:</td>\n      <td>227,943,824 km (1.52 AU)</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Orbit Period:</td>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Surface Temperature:</td>\n      <td>-153 to 20 °C</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>First Record:</td>\n      <td>2nd millennium BC</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Recorded By:</td>\n      <td>Egyptian astronomers</td>\n    </tr>\n  </tbody>\n</table>'

# %%
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Fact</th>      <th>Value</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>Equatorial Diameter:</td>      <td>6,792 km</td>    </tr>    <tr>      <th>1</th>      <td>Polar Diameter:</td>      <td>6,752 km</td>    </tr>    <tr>      <th>2</th>      <td>Mass:</td>      <td>6.42 x 10^23 kg (10.7% Earth)</td>    </tr>    <tr>      <th>3</th>      <td>Moons:</td>      <td>2 (Phobos &amp; Deimos)</td>    </tr>    <tr>      <th>4</th>      <td>Orbit Distance:</td>      <td>227,943,824 km (1.52 AU)</td>    </tr>    <tr>      <th>5</th>      <td>Orbit Period:</td>      <td>687 days (1.9 years)</td>    </tr>    <tr>      <th>6</th>      <td>Surface Temperature:</td>      <td>-153 to 20 °C</td>    </tr>    <tr>      <th>7</th>      <td>First Record:</td>      <td>2nd millennium BC</td>    </tr>    <tr>      <th>8</th>      <td>Recorded By:</td>      <td>Egyptian astronomers</td>    </tr>  </tbody></table>'

# %%
df.to_html('table.html')

# %%
l={}
for x in tables[0]:
    #print(x)
    l[x]=[]
    for y in tables[0][x]:
        l[x].append(y)
        #print(y)
#print(l)
MarsFacts=[]
for i in range(len(l["Fact"])):
    MarsFacts.append((l["Fact"][i].replace(":", ""),l["Value"][i]))
    
print(MarsFacts)
# Out:
# [('Equatorial Diameter', '6,792 km'), ('Polar Diameter', '6,752 km'), ('Mass', '6.42 x 10^23 kg (10.7% Earth)'), ('Moons', '2 (Phobos & Deimos)'), ('Orbit Distance', '227,943,824 km (1.52 AU)'), ('Orbit Period', '687 days (1.9 years)'), ('Surface Temperature', '-153 to 20 °C'), ('First Record', '2nd millennium BC'), ('Recorded By', 'Egyptian astronomers')]

# %% [markdown]
# ## Mars Hemispheres

# %%
url = "https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
images = soup.find_all('div', class_='item')

hemisphere_image_urls = []
for div in images:
    title = div.find('a', class_='itemLink').find('h3').text
    image = div.find('a', class_='itemLink').find('img')
    link = div.find('a', class_='itemLink')
    link = "https://astrogeology.usgs.gov" + link["href"]
    news_image = "https://astrogeology.usgs.gov" + image["src"]
    response2 = requests.get(link)
    soup2 = BeautifulSoup(response2.text, "html.parser")
    image2 = soup2.find('div', class_='downloads').find('li').find('a')
    link2 = image2["href"]
    #print(news_image, link2)
    hemisphere_image_urls.append({
        "title":title,
        "link":link,
        "full_image":link2,
        "img_url":news_image
    })
print("-"*64)
print(hemisphere_image_urls)
# Out:
# ----------------------------------------------------------------
# [{'title': 'Cerberus Hemisphere Enhanced', 'link': 'https://astrogeology.usgs.gov/search/map/Mars/Viking/cerberus_enhanced', 'full_image': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg', 'img_url': 'https://astrogeology.usgs.gov/cache/images/dfaf3849e74bf973b59eb50dab52b583_cerberus_enhanced.tif_thumb.png'}, {'title': 'Schiaparelli Hemisphere Enhanced', 'link': 'https://astrogeology.usgs.gov/search/map/Mars/Viking/schiaparelli_enhanced', 'full_image': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg', 'img_url': 'https://astrogeology.usgs.gov/cache/images/7677c0a006b83871b5a2f66985ab5857_schiaparelli_enhanced.tif_thumb.png'}, {'title': 'Syrtis Major Hemisphere Enhanced', 'link': 'https://astrogeology.usgs.gov/search/map/Mars/Viking/syrtis_major_enhanced', 'full_image': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg', 'img_url': 'https://astrogeology.usgs.gov/cache/images/aae41197e40d6d4f3ea557f8cfe51d15_syrtis_major_enhanced.tif_thumb.png'}, {'title': 'Valles Marineris Hemisphere Enhanced', 'link': 'https://astrogeology.usgs.gov/search/map/Mars/Viking/valles_marineris_enhanced', 'full_image': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg', 'img_url': 'https://astrogeology.usgs.gov/cache/images/04085d99ec3713883a9a57f42be9c725_valles_marineris_enhanced.tif_thumb.png'}]
